# %%
import os
import time
import re
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service

# === CONFIGURATION ===
BASE_URL        = "https://www.mql5.com"
START_URL       = f"{BASE_URL}/en/code/mt5/indicators"
# Il y a 137 pages d'indicateurs
PAGES_TO_SCRAPE = 137
DOWNLOAD_ROOT   = "mql5_indicators_mt5"
PAGE_DELAY      = 2       # secondes d’attente après chargement de chaque page
REQ_TIMEOUT     = 30      # timeout pour requests.get

# === UTILITAIRES ===
def safe_mkdir(path):
    if not os.path.isdir(path):
        os.makedirs(path, exist_ok=True)

def download_file(url, dest_folder):
    safe_mkdir(dest_folder)
    filename = os.path.basename(urlparse(url).path)
    dest_path = os.path.join(dest_folder, filename)
    print(f"[↓] {filename} ← {url}")
    try:
        r = requests.get(url, stream=True, timeout=REQ_TIMEOUT)
        r.raise_for_status()
        with open(dest_path, "wb") as f:
            for chunk in r.iter_content(1024):
                f.write(chunk)
        print(f"[✔] Téléchargé: {filename}")
    except Exception as e:
        print(f"[✘] Erreur download {filename}: {e}")

# === SETUP SELENIUM HEADLESS ===
chrome_opts = Options()
chrome_opts.add_argument("--headless")
chrome_opts.add_argument("--disable-gpu")
chrome_opts.add_argument("--no-sandbox")
driver = webdriver.Chrome(service=Service(), options=chrome_opts)

# === CRÉER LE DOSSIER RACINE ===
safe_mkdir(DOWNLOAD_ROOT)

# === SCRAPING PAGES ===
for idx in range(1, PAGES_TO_SCRAPE + 1):
    page_url = START_URL if idx == 1 else f"{START_URL}/page{idx}"
    print(f"\n=== Scraping page {idx}/{PAGES_TO_SCRAPE}: {page_url}")
    driver.get(page_url)
    time.sleep(PAGE_DELAY)

    soup = BeautifulSoup(driver.page_source, "html.parser")
    tiles = soup.select(".codebase-list__content .code-tile .title > a")
    print(f"-- {len(tiles)} indicateurs trouvés")

    for a in tiles:
        href = a.get("href")
        list_title = a.text.strip()
        indicator_url = urljoin(BASE_URL, href)
        print(f"\n→ Indicateur: {indicator_url}")
        driver.get(indicator_url)
        time.sleep(PAGE_DELAY)
        esoup = BeautifulSoup(driver.page_source, "html.parser")

        # Nom de l’indicateur: priorité au <h1>, sinon titre depuis la liste
        h1 = esoup.select_one("h1")
        if h1 and h1.text.strip():
            name_raw = h1.text.strip()
        else:
            name_raw = list_title or href.split('/')[-1]
            print(f"   [ℹ] Pas de <h1> trouvé, utilisation du titre listé: '{name_raw}'")
        name = re.sub(r"[\\/:*?\"<>|]", "_", name_raw)
        folder = os.path.join(DOWNLOAD_ROOT, name)
        safe_mkdir(folder)
        print(f"   ▶ Dossier: {folder}")

        # Télécharger le code : ZIP ou .mq5/.mq4
        zip_link = esoup.find("a", string=re.compile(r"Download as ZIP", re.I))
        if zip_link and zip_link.get("href"):
            download_file(urljoin(BASE_URL, zip_link["href"]), folder)
        else:
            code_link = esoup.find("a", href=re.compile(r"\.mq[45]$"))
            if code_link:
                download_file(urljoin(BASE_URL, code_link["href"]), folder)
            else:
                print("   [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).")

        # Télécharger les images de présentation
        images = esoup.select(".codebase-detail img")
        print(f"   ▶ {len(images)} images détectées")
        for img in images:
            src = img.get("src") or img.get("data-src")
            if not src or not re.search(r"\.(png|jpe?g|gif)$", src, re.I):
                continue
            download_file(urljoin(BASE_URL, src), folder)

# === FIN ===
driver.quit()
print("\n=== FIN DU SCRAPING INDICATEURS ===")
# Out:
# === Scraping page 1/137: https://www.mql5.com/en/code/mt5/indicators
# -- 40 indicateurs trouvés
#
# → Indicateur: https://www.mql5.com/en/code/56228
#    ▶ Dossier: mql5_indicators_mt5\Price Time Scale - indicator for MetaTrader 5
# [↓] pricetimescale.mq5 ← https://www.mql5.com/en/code/download/56228/pricetimescale.mq5
# [✔] Téléchargé: pricetimescale.mq5
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56281
#    ▶ Dossier: mql5_indicators_mt5\Candle size - indicator for MetaTrader 5
# [↓] candle_size.mq5 ← https://www.mql5.com/en/code/download/56281/candle_size.mq5
# [✔] Téléchargé: candle_size.mq5
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56382
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'MACD coloured histogram'
#    ▶ Dossier: mql5_indicators_mt5\MACD coloured histogram
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56432
#    ▶ Dossier: mql5_indicators_mt5\Candle Counter - indicator for MetaTrader 5
# [↓] candle_counter.mq5 ← https://www.mql5.com/en/code/download/56432/candle_counter.mq5
# [✔] Téléchargé: candle_counter.mq5
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/60537
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Moving Average based on Heiken-Ashi'
#    ▶ Dossier: mql5_indicators_mt5\Moving Average based on Heiken-Ashi
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/60369
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Supertrend by KivancOzbilgic'
#    ▶ Dossier: mql5_indicators_mt5\Supertrend by KivancOzbilgic
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56820
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Divergence Awesome Ocilator'
#    ▶ Dossier: mql5_indicators_mt5\Divergence Awesome Ocilator
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56909
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Daily Trend'
#    ▶ Dossier: mql5_indicators_mt5\Daily Trend
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/60194
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'ATR Channels Indicator'
#    ▶ Dossier: mql5_indicators_mt5\ATR Channels Indicator
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/54459
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'AlphaTrend'
#    ▶ Dossier: mql5_indicators_mt5\AlphaTrend
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56972
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'False Breakups'
#    ▶ Dossier: mql5_indicators_mt5\False Breakups
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/60054
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Baseline: iMA + ATR Bands'
#    ▶ Dossier: mql5_indicators_mt5\Baseline_ iMA + ATR Bands
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/60023
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Show Positions on Custom Chart (or standard chart) for MT5'
#    ▶ Dossier: mql5_indicators_mt5\Show Positions on Custom Chart (or standard chart) for MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57174
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Divergence DeMarker'
#    ▶ Dossier: mql5_indicators_mt5\Divergence DeMarker
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/58896
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Change the colour of candles and wick'
#    ▶ Dossier: mql5_indicators_mt5\Change the colour of candles and wick
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/58845
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Customised bmap chart'
#    ▶ Dossier: mql5_indicators_mt5\Customised bmap chart
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/59733
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Engulfing Pattern Indicator with Volume Confirmation'
#    ▶ Dossier: mql5_indicators_mt5\Engulfing Pattern Indicator with Volume Confirmation
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/59792
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Trendline zigzag in qualitative channel'
#    ▶ Dossier: mql5_indicators_mt5\Trendline zigzag in qualitative channel
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/59744
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Equity and Balance Indicator - History based'
#    ▶ Dossier: mql5_indicators_mt5\Equity and Balance Indicator - History based
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/58516
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Candle Filter'
#    ▶ Dossier: mql5_indicators_mt5\Candle Filter
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/58104
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'RSI Divergence'
#    ▶ Dossier: mql5_indicators_mt5\RSI Divergence
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/58229
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'EquiPeak Drawdown Tracker'
#    ▶ Dossier: mql5_indicators_mt5\EquiPeak Drawdown Tracker
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/59477
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'DailyHighLow Indicator for MQL5'
#    ▶ Dossier: mql5_indicators_mt5\DailyHighLow Indicator for MQL5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/59368
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Swaps Monitor for a Single Symbol'
#    ▶ Dossier: mql5_indicators_mt5\Swaps Monitor for a Single Symbol
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/59342
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'ADX Indicator (MQL5)'
#    ▶ Dossier: mql5_indicators_mt5\ADX Indicator (MQL5)
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/59268
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Custom MACD: Elevate Your Trading with Real-Time Signal Alerts to Your Phone'
#    ▶ Dossier: mql5_indicators_mt5\Custom MACD_ Elevate Your Trading with Real-Time Signal Alerts to Your Phone
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/59227
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'BBMA - Bollinger Band Moving Average'
#    ▶ Dossier: mql5_indicators_mt5\BBMA - Bollinger Band Moving Average
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/59204
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Range BreakOut Indicator - Indicator Buffer Only'
#    ▶ Dossier: mql5_indicators_mt5\Range BreakOut Indicator - Indicator Buffer Only
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/59157
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Multi-Day Dynamic VWAP'
#    ▶ Dossier: mql5_indicators_mt5\Multi-Day Dynamic VWAP
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/58838
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Brooky Trend Strength for MT5'
#    ▶ Dossier: mql5_indicators_mt5\Brooky Trend Strength for MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/58789
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'SignalAI - Indicator'
#    ▶ Dossier: mql5_indicators_mt5\SignalAI - Indicator
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/58636
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Custom MA Cross with RSI Indicator for MT5'
#    ▶ Dossier: mql5_indicators_mt5\Custom MA Cross with RSI Indicator for MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/58650
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'CTJM Candle Timer'
#    ▶ Dossier: mql5_indicators_mt5\CTJM Candle Timer
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/58562
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Volume MA with candle color tracking'
#    ▶ Dossier: mql5_indicators_mt5\Volume MA with candle color tracking
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57731
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Countdown 2.0'
#    ▶ Dossier: mql5_indicators_mt5\Countdown 2.0
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57644
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'MACD Divergence'
#    ▶ Dossier: mql5_indicators_mt5\MACD Divergence
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57620
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Spreads'
#    ▶ Dossier: mql5_indicators_mt5\Spreads
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57320
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'AveragePrice'
#    ▶ Dossier: mql5_indicators_mt5\AveragePrice
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56678
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Better volume'
#    ▶ Dossier: mql5_indicators_mt5\Better volume
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/49558
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Volatility Stop'
#    ▶ Dossier: mql5_indicators_mt5\Volatility Stop
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# === Scraping page 2/137: https://www.mql5.com/en/code/mt5/indicators/page2
# -- 40 indicateurs trouvés
#
# → Indicateur: https://www.mql5.com/en/code/49404
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'SMI Ergodic Oscillator'
#    ▶ Dossier: mql5_indicators_mt5\SMI Ergodic Oscillator
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/49334
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Net Volume'
#    ▶ Dossier: mql5_indicators_mt5\Net Volume
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/49265
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Know Sure Thing'
#    ▶ Dossier: mql5_indicators_mt5\Know Sure Thing
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/49182
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Correlation Coefficient'
#    ▶ Dossier: mql5_indicators_mt5\Correlation Coefficient
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/49029
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Chaikin Money Flow'
#    ▶ Dossier: mql5_indicators_mt5\Chaikin Money Flow
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/58257
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'ColorXMA_Ishimoku_StDev - indicator for MetaTrader 5'
#    ▶ Dossier: mql5_indicators_mt5\ColorXMA_Ishimoku_StDev - indicator for MetaTrader 5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/49459
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Volume Oscillator'
#    ▶ Dossier: mql5_indicators_mt5\Volume Oscillator
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/58231
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'EquiPeak Drawdown Tracker'
#    ▶ Dossier: mql5_indicators_mt5\EquiPeak Drawdown Tracker
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/54894
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Kuskus Starlight'
#    ▶ Dossier: mql5_indicators_mt5\Kuskus Starlight
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/49175
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Chande Kroll Stop'
#    ▶ Dossier: mql5_indicators_mt5\Chande Kroll Stop
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/49132
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'PriceChanges'
#    ▶ Dossier: mql5_indicators_mt5\PriceChanges
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/48962
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Second Bars'
#    ▶ Dossier: mql5_indicators_mt5\Second Bars
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57975
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Uniformity Factor Indicator'
#    ▶ Dossier: mql5_indicators_mt5\Uniformity Factor Indicator
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/49985
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Angle and Speed'
#    ▶ Dossier: mql5_indicators_mt5\Angle and Speed
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/25229
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Pan PrizMA No leverage 72'
#    ▶ Dossier: mql5_indicators_mt5\Pan PrizMA No leverage 72
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57724
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'PSAR Zigzag (Non lagging)'
#    ▶ Dossier: mql5_indicators_mt5\PSAR Zigzag (Non lagging)
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57684
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Ranging Market Detector'
#    ▶ Dossier: mql5_indicators_mt5\Ranging Market Detector
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57597
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Breakout Finder by LonesomeTheBlue'
#    ▶ Dossier: mql5_indicators_mt5\Breakout Finder by LonesomeTheBlue
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57377
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'FVG based Momentum Detection'
#    ▶ Dossier: mql5_indicators_mt5\FVG based Momentum Detection
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57302
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Trend Zigzag (on ma cross)'
#    ▶ Dossier: mql5_indicators_mt5\Trend Zigzag (on ma cross)
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57063
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Supertrend'
#    ▶ Dossier: mql5_indicators_mt5\Supertrend
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/57038
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'BarDuration'
#    ▶ Dossier: mql5_indicators_mt5\BarDuration
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56927
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'T3 Moving Average'
#    ▶ Dossier: mql5_indicators_mt5\T3 Moving Average
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56869
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Daily Vertical Lines'
#    ▶ Dossier: mql5_indicators_mt5\Daily Vertical Lines
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56619
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Fibonacci ZigZag'
#    ▶ Dossier: mql5_indicators_mt5\Fibonacci ZigZag
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56616
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Autoscaling Zigzag'
#    ▶ Dossier: mql5_indicators_mt5\Autoscaling Zigzag
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56559
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Time To Close v1.01 - MT5'
#    ▶ Dossier: mql5_indicators_mt5\Time To Close v1.01 - MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/56289
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Self Optimized SMA'
#    ▶ Dossier: mql5_indicators_mt5\Self Optimized SMA
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/55923
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Intrabar Volume Flow'
#    ▶ Dossier: mql5_indicators_mt5\Intrabar Volume Flow
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/55521
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Trade Assistant MT5'
#    ▶ Dossier: mql5_indicators_mt5\Trade Assistant MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/55622
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Portable Moving Average'
#    ▶ Dossier: mql5_indicators_mt5\Portable Moving Average
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/55519
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Total Power Indicator MT5'
#    ▶ Dossier: mql5_indicators_mt5\Total Power Indicator MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/55517
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'TD Sequential Ultimate MT5'
#    ▶ Dossier: mql5_indicators_mt5\TD Sequential Ultimate MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/55371
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Coppock MT5 indicator'
#    ▶ Dossier: mql5_indicators_mt5\Coppock MT5 indicator
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/55515
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Support and Resistance MT5'
#    ▶ Dossier: mql5_indicators_mt5\Support and Resistance MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/55513
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Spread indicator MT5'
#    ▶ Dossier: mql5_indicators_mt5\Spread indicator MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/55511
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Schaff Trend Cycle MT5'
#    ▶ Dossier: mql5_indicators_mt5\Schaff Trend Cycle MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/55509
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'RSIOMA MT5'
#    ▶ Dossier: mql5_indicators_mt5\RSIOMA MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/55507
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Round Levels MT5'
#    ▶ Dossier: mql5_indicators_mt5\Round Levels MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# → Indicateur: https://www.mql5.com/en/code/55504
#    [ℹ] Pas de <h1> trouvé, utilisation du titre listé: 'Recent High/Low Alert MT5'
#    ▶ Dossier: mql5_indicators_mt5\Recent High_Low Alert MT5
#    [!] Aucun code trouvé (.mq5/.mq4 ou ZIP).
#    ▶ 0 images détectées
#
# === Scraping page 3/137: https://www.mql5.com/en/code/mt5/indicators/page3
# -- 0 indicateurs trouvés
#
# === Scraping page 4/137: https://www.mql5.com/en/code/mt5/indicators/page4
# -- 0 indicateurs trouvés
#
# === Scraping page 5/137: https://www.mql5.com/en/code/mt5/indicators/page5
# -- 0 indicateurs trouvés
#
# === Scraping page 6/137: https://www.mql5.com/en/code/mt5/indicators/page6
# -- 0 indicateurs trouvés
#
# === Scraping page 7/137: https://www.mql5.com/en/code/mt5/indicators/page7
# -- 0 indicateurs trouvés
#
# === Scraping page 8/137: https://www.mql5.com/en/code/mt5/indicators/page8
# -- 0 indicateurs trouvés
#
# === Scraping page 9/137: https://www.mql5.com/en/code/mt5/indicators/page9
# -- 0 indicateurs trouvés
#
# === Scraping page 10/137: https://www.mql5.com/en/code/mt5/indicators/page10
# -- 0 indicateurs trouvés
#
# === Scraping page 11/137: https://www.mql5.com/en/code/mt5/indicators/page11
# -- 0 indicateurs trouvés
#
# === Scraping page 12/137: https://www.mql5.com/en/code/mt5/indicators/page12
# -- 0 indicateurs trouvés
#
# === Scraping page 13/137: https://www.mql5.com/en/code/mt5/indicators/page13
# -- 0 indicateurs trouvés
#
# === Scraping page 14/137: https://www.mql5.com/en/code/mt5/indicators/page14
# -- 0 indicateurs trouvés
#
# === Scraping page 15/137: https://www.mql5.com/en/code/mt5/indicators/page15
# -- 0 indicateurs trouvés
#
# === Scraping page 16/137: https://www.mql5.com/en/code/mt5/indicators/page16
# -- 0 indicateurs trouvés
#
# === Scraping page 17/137: https://www.mql5.com/en/code/mt5/indicators/page17
# -- 0 indicateurs trouvés
#
# === Scraping page 18/137: https://www.mql5.com/en/code/mt5/indicators/page18
# -- 0 indicateurs trouvés
#
# === Scraping page 19/137: https://www.mql5.com/en/code/mt5/indicators/page19
# -- 0 indicateurs trouvés
#
# === Scraping page 20/137: https://www.mql5.com/en/code/mt5/indicators/page20
# -- 0 indicateurs trouvés
#
# === Scraping page 21/137: https://www.mql5.com/en/code/mt5/indicators/page21
# -- 0 indicateurs trouvés
#
# === Scraping page 22/137: https://www.mql5.com/en/code/mt5/indicators/page22
# -- 0 indicateurs trouvés
#
# === Scraping page 23/137: https://www.mql5.com/en/code/mt5/indicators/page23
# -- 0 indicateurs trouvés
#
# === Scraping page 24/137: https://www.mql5.com/en/code/mt5/indicators/page24
# -- 0 indicateurs trouvés
#
# === Scraping page 25/137: https://www.mql5.com/en/code/mt5/indicators/page25
# -- 0 indicateurs trouvés
#
# === Scraping page 26/137: https://www.mql5.com/en/code/mt5/indicators/page26
# -- 0 indicateurs trouvés
#
# === Scraping page 27/137: https://www.mql5.com/en/code/mt5/indicators/page27
# -- 0 indicateurs trouvés
#
# === Scraping page 28/137: https://www.mql5.com/en/code/mt5/indicators/page28
# -- 0 indicateurs trouvés
#
# === Scraping page 29/137: https://www.mql5.com/en/code/mt5/indicators/page29
# -- 0 indicateurs trouvés
#
# === Scraping page 30/137: https://www.mql5.com/en/code/mt5/indicators/page30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 55
#      53 print(f"\n=== Scraping page {idx}/{PAGES_TO_SCRAPE}: {page_url}")
#      54 driver.get(page_url)
# ---> 55 time.sleep(PAGE_DELAY)
#      57 soup = BeautifulSoup(driver.page_source, "html.parser")
#      58 tiles = soup.select(".codebase-list__content .code-tile .title > a")
#
# KeyboardInterrupt:
